# %% [markdown]
# <h1>Pandas</h1>

# %%
import pandas as pd

# %%
d=pd.read_csv("C://Users//Harish//Downloads//StatewiseTestingDetails.csv")
df=pd.DataFrame(d)

# %%
df.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
df.head(2)
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0

# %%
df.tail()
# Out:
#              Date        State  TotalSamples Negative  Positive
# 16331  2021-08-06  West Bengal    15999961.0      NaN       NaN
# 16332  2021-08-07  West Bengal    16045662.0      NaN       NaN
# 16333  2021-08-08  West Bengal    16092192.0      NaN       NaN
# 16334  2021-08-09  West Bengal    16122345.0      NaN       NaN
# 16335  2021-08-10  West Bengal    16162814.0      NaN       NaN

# %%
df.tail(2)
# Out:
#              Date        State  TotalSamples Negative  Positive
# 16334  2021-08-09  West Bengal    16122345.0      NaN       NaN
# 16335  2021-08-10  West Bengal    16162814.0      NaN       NaN

# %%
df.describe().transpose()
# Out:
#                 count          mean           std   min        25%       50%  \
# TotalSamples  16336.0  5.376466e+06  8.780338e+06  58.0  172909.75  930758.0
# Positive       5662.0  5.652654e+04  1.673108e+05   0.0     536.25    4771.0
#
#                      75%         max
# TotalSamples  7284795.25  67897856.0
# Positive        33618.75   1638961.0

# %%
df.shape
# Out:
# (16336, 5)

# %%
df[0:10:2]
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# 6  2020-05-20  Andaman and Nicobar Islands        7082.0      NaN      33.0
# 8  2020-05-22  Andaman and Nicobar Islands        7263.0      NaN      33.0

# %%
df['TotalSamples']
# Out:
# 0            1403.0
# 1            2679.0
# 2            2848.0
# 3            3754.0
# 4            6677.0
#             ...
# 16331    15999961.0
# 16332    16045662.0
# 16333    16092192.0
# 16334    16122345.0
# 16335    16162814.0
# Name: TotalSamples, Length: 16336, dtype: float64

# %%
df[['Negative','Positive']]
# Out:
#       Negative  Positive
# 0         1210      12.0
# 1          NaN      27.0
# 2          NaN      33.0
# 3          NaN      33.0
# 4          NaN      33.0
# ...        ...       ...
# 16331      NaN       NaN
# 16332      NaN       NaN
# 16333      NaN       NaN
# 16334      NaN       NaN
# 16335      NaN       NaN
#
# [16336 rows x 2 columns]

# %%
df[['State','Negative','Positive']]
# Out:
#                              State Negative  Positive
# 0      Andaman and Nicobar Islands     1210      12.0
# 1      Andaman and Nicobar Islands      NaN      27.0
# 2      Andaman and Nicobar Islands      NaN      33.0
# 3      Andaman and Nicobar Islands      NaN      33.0
# 4      Andaman and Nicobar Islands      NaN      33.0
# ...                            ...      ...       ...
# 16331                  West Bengal      NaN       NaN
# 16332                  West Bengal      NaN       NaN
# 16333                  West Bengal      NaN       NaN
# 16334                  West Bengal      NaN       NaN
# 16335                  West Bengal      NaN       NaN
#
# [16336 rows x 3 columns]

# %%
df[['State','Negative','Positive']][0:10:2]
# Out:
#                          State Negative  Positive
# 0  Andaman and Nicobar Islands     1210      12.0
# 2  Andaman and Nicobar Islands      NaN      33.0
# 4  Andaman and Nicobar Islands      NaN      33.0
# 6  Andaman and Nicobar Islands      NaN      33.0
# 8  Andaman and Nicobar Islands      NaN      33.0

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, Date                             2020-04-17
# State           Andaman and Nicobar Islands
# TotalSamples                         1403.0
# Negative                               1210
# Positive                               12.0
# Name: 0, dtype: object)
# (1, Date                             2020-04-24
# State           Andaman and Nicobar Islands
# TotalSamples                         2679.0
# Negative                                NaN
# Positive                               27.0
# Name: 1, dtype: object)
# (2, Date                             2020-04-27
# State           Andaman and Nicobar Islands
# TotalSamples                         2848.0
# Negative                                NaN
# Positive                               33.0
# Name: 2, dtype: object)
# (3, Date                             2020-05-01
# State           Andaman and Nicobar Islands
# TotalSamples                         3754.0
# Negative                                NaN
# ...

# %% [markdown]
# <h1>LOC</h1>

# %%
df.loc[4]
# Out:
# Date                             2020-05-16
# State           Andaman and Nicobar Islands
# TotalSamples                         6677.0
# Negative                                NaN
# Positive                               33.0
# Name: 4, dtype: object

# %%
df.loc[4,['State']]
# Out:
# State    Andaman and Nicobar Islands
# Name: 4, dtype: object

# %%
df.loc[0:6]
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# 5  2020-05-19  Andaman and Nicobar Islands        6965.0      NaN      33.0
# 6  2020-05-20  Andaman and Nicobar Islands        7082.0      NaN      33.0

# %%
df.loc[0:6,['State','Positive']]
# Out:
#                          State  Positive
# 0  Andaman and Nicobar Islands      12.0
# 1  Andaman and Nicobar Islands      27.0
# 2  Andaman and Nicobar Islands      33.0
# 3  Andaman and Nicobar Islands      33.0
# 4  Andaman and Nicobar Islands      33.0
# 5  Andaman and Nicobar Islands      33.0
# 6  Andaman and Nicobar Islands      33.0

# %%
df.loc[0:5,'State':'TotalSamples']
# Out:
#                          State  TotalSamples
# 0  Andaman and Nicobar Islands        1403.0
# 1  Andaman and Nicobar Islands        2679.0
# 2  Andaman and Nicobar Islands        2848.0
# 3  Andaman and Nicobar Islands        3754.0
# 4  Andaman and Nicobar Islands        6677.0
# 5  Andaman and Nicobar Islands        6965.0

# %% [markdown]
# <h1>ILOC</h1>

# %%
df.iloc[0:5]
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
df.iloc[1,4]
# Out:
# 27.0

# %%
df.iloc[0:4,0:2]
# Out:
#          Date                        State
# 0  2020-04-17  Andaman and Nicobar Islands
# 1  2020-04-24  Andaman and Nicobar Islands
# 2  2020-04-27  Andaman and Nicobar Islands
# 3  2020-05-01  Andaman and Nicobar Islands

# %%
df.iloc[0:4,2]
# Out:
# 0    1403.0
# 1    2679.0
# 2    2848.0
# 3    3754.0
# Name: TotalSamples, dtype: float64

# %%
df.iloc[[1,2,4,5]]
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# 5  2020-05-19  Andaman and Nicobar Islands        6965.0      NaN      33.0

# %%
df.iloc[:,[2,4]]
# Out:
#        TotalSamples  Positive
# 0            1403.0      12.0
# 1            2679.0      27.0
# 2            2848.0      33.0
# 3            3754.0      33.0
# 4            6677.0      33.0
# ...             ...       ...
# 16331    15999961.0       NaN
# 16332    16045662.0       NaN
# 16333    16092192.0       NaN
# 16334    16122345.0       NaN
# 16335    16162814.0       NaN
#
# [16336 rows x 2 columns]

# %%
df.iloc[0:4,[1,4]]
# Out:
#                          State  Positive
# 0  Andaman and Nicobar Islands      12.0
# 1  Andaman and Nicobar Islands      27.0
# 2  Andaman and Nicobar Islands      33.0
# 3  Andaman and Nicobar Islands      33.0

# %% [markdown]
# <h1>Sorting The DataFrame</h1>

# %%
df.sort_values('Positive')
# Out:
#              Date        State  TotalSamples Negative  Positive
# 10659  2020-04-12     Nagaland          74.0       70       0.0
# 10691  2020-05-17     Nagaland         952.0      914       0.0
# 10692  2020-05-18     Nagaland         961.0      914       0.0
# 10693  2020-05-19     Nagaland         978.0      948       0.0
# 10694  2020-05-20     Nagaland         985.0      952       0.0
# ...           ...          ...           ...      ...       ...
# 16331  2021-08-06  West Bengal    15999961.0      NaN       NaN
# 16332  2021-08-07  West Bengal    16045662.0      NaN       NaN
# 16333  2021-08-08  West Bengal    16092192.0      NaN       NaN
# 16334  2021-08-09  West Bengal    16122345.0      NaN       NaN
# 16335  2021-08-10  West Bengal    16162814.0      NaN       NaN
#
# [16336 rows x 5 columns]

# %%
df.sort_values('Positive',ascending=False)
# Out:
#              Date        State  TotalSamples Negative   Positive
# 9088   2020-10-24  Maharashtra     8548036.0      NaN  1638961.0
# 9087   2020-10-23  Maharashtra     8479155.0      NaN  1632544.0
# 9084   2020-10-20  Maharashtra     8251234.0  6641718  1609516.0
# 9082   2020-10-18  Maharashtra     8139466.0  6544085  1595381.0
# 9081   2020-10-17  Maharashtra     8069100.0  6482779  1586321.0
# ...           ...          ...           ...      ...        ...
# 16331  2021-08-06  West Bengal    15999961.0      NaN        NaN
# 16332  2021-08-07  West Bengal    16045662.0      NaN        NaN
# 16333  2021-08-08  West Bengal    16092192.0      NaN        NaN
# 16334  2021-08-09  West Bengal    16122345.0      NaN        NaN
# 16335  2021-08-10  West Bengal    16162814.0      NaN        NaN
#
# [16336 rows x 5 columns]

# %%
df.sort_values(['Negative','Positive'])
# Out:
#              Date           State  TotalSamples  Negative  Positive
# 10725  2020-06-20        Nagaland        9128.0               201.0
# 10191  2020-04-06         Mizoram          58.0         0       1.0
# 10192  2020-04-07         Mizoram          58.0         0       1.0
# 9789   2020-04-23       Meghalaya        1109.0      1000      12.0
# 701    2020-12-14  Andhra Pradesh    10875925.0  10000089       NaN
# ...           ...             ...           ...       ...       ...
# 16331  2021-08-06     West Bengal    15999961.0       NaN       NaN
# 16332  2021-08-07     West Bengal    16045662.0       NaN       NaN
# 16333  2021-08-08     West Bengal    16092192.0       NaN       NaN
# 16334  2021-08-09     West Bengal    16122345.0       NaN       NaN
# 16335  2021-08-10     West Bengal    16162814.0       NaN       NaN
#
# [16336 rows x 5 columns]

# %% [markdown]
# <h1>Manupulating DataFrame</h1>

# %%
#we can add,delete and modify the coloumns
df['Total']=0
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %%
#Deleting coloumn
df['Perc']='pass/fail'
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total       Perc
# 0          12.0      0  pass/fail
# 1          27.0      0  pass/fail
# ...

# %%
df.drop(columns='Perc')
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %%
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total       Perc
# 0          12.0      0  pass/fail
# 1          27.0      0  pass/fail
# ...

# %%
df.drop(columns='Perc',inplace=True)

# %%
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %%
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %% [markdown]
# <h1>Removing Duplicates</h1>

# %%
#knowing Duplicates
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16331    False
# 16332    False
# 16333    False
# 16334    False
# 16335    False
# Length: 16336, dtype: bool

# %%
#Removing Duplicates
df.drop_duplicates()
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %% [markdown]
# <h1>Handiling Missing Data</h1>

# %%
#Filling with default value
df.fillna(1200)
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0     1200
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0     1200
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0     1200
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0     1200
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0     1200
# 16332  2021-08-07                  West Bengal    16045662.0     1200
# 16333  2021-08-08                  West Bengal    16092192.0     1200
# 16334  2021-08-09                  West Bengal    16122345.0     1200
# 16335  2021-08-10                  West Bengal    16162814.0     1200
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %%
df['Negative'].fillna(1200)
# Out:
# 0        1210
# 1        1200
# 2        1200
# 3        1200
# 4        1200
#          ...
# 16331    1200
# 16332    1200
# 16333    1200
# 16334    1200
# 16335    1200
# Name: Negative, Length: 16336, dtype: object

# %%
#Droping Missing Data
df.dropna()
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 453    2020-04-02               Andhra Pradesh        1800.0     1175
# 454    2020-04-10               Andhra Pradesh        6374.0     6009
# 455    2020-04-11               Andhra Pradesh        6958.0     6577
# 456    2020-04-12               Andhra Pradesh        6958.0     6553
# ...           ...                          ...           ...      ...
# 15482  2020-08-15                  Uttarakhand      256008.0   225614
# 15483  2020-08-16                  Uttarakhand      260790.0   229387
# 15488  2020-08-21                  Uttarakhand      294279.0   258971
# 15528  2020-09-30                  Uttarakhand      712124.0   637547
# 15843  2020-04-01                  West Bengal         659.0      568
#
#        Positive  Total
# 0          12.0      0
# 453       132.0      0
# 454       365.0      0
# 455       381.0      0
# ...

# %%
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive  Total
# 0          12.0      0
# 1          27.0      0
# 2          33.0      0
# 3          33.0      0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 453    2020-04-02               Andhra Pradesh        1800.0     1175
# 454    2020-04-10               Andhra Pradesh        6374.0     6009
# 455    2020-04-11               Andhra Pradesh        6958.0     6577
# 456    2020-04-12               Andhra Pradesh        6958.0     6553
# ...           ...                          ...           ...      ...
# 15482  2020-08-15                  Uttarakhand      256008.0   225614
# 15483  2020-08-16                  Uttarakhand      260790.0   229387
# 15488  2020-08-21                  Uttarakhand      294279.0   258971
# 15528  2020-09-30                  Uttarakhand      712124.0   637547
# 15843  2020-04-01                  West Bengal         659.0      568
#
#        Positive  Total
# 0          12.0      0
# 453       132.0      0
# 454       365.0      0
# 455       381.0      0
# ...

# %% [markdown]
# <h1>Data Filtering & Conditional Changes</h1>

# %%
df.loc[df['Positive']>50000]
# Out:
#              Date           State  TotalSamples Negative  Positive  Total
# 554    2020-07-20  Andhra Pradesh     1349112.0  1295388   53724.0      0
# 555    2020-07-21  Andhra Pradesh     1386274.0  1327606   58668.0      0
# 556    2020-07-22  Andhra Pradesh     1435827.0  1371114   64713.0      0
# 557    2020-07-23  Andhra Pradesh     1493879.0  1421168   72711.0      0
# 558    2020-07-24  Andhra Pradesh     1541993.0  1461135   80858.0      0
# ...           ...             ...           ...      ...       ...    ...
# 14857  2021-08-06         Tripura     1606029.0  1526255   79774.0      0
# 14858  2021-08-07         Tripura     1613036.0  1533091   79945.0      0
# 14859  2021-08-08         Tripura     1619189.0  1539058   80131.0      0
# 14860  2021-08-09         Tripura     1622625.0  1542417   80208.0      0
# 14861  2021-08-10         Tripura     1630572.0  1550159   80413.0      0
#
# [606 rows x 6 columns]

# %%
df.loc[(df['Negative']>2000000) & (df['Positive']<30000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 df.loc[(df['Negative']>2000000) & (df['Positive']<30000)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:5804, in Series._cmp_method(self, other, op)
#    5801 lvalues = self._values
# ...

# %%
df.loc[df['State'].str.contains('a')]
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 453    2020-04-02               Andhra Pradesh        1800.0     1175
# 454    2020-04-10               Andhra Pradesh        6374.0     6009
# 455    2020-04-11               Andhra Pradesh        6958.0     6577
# 456    2020-04-12               Andhra Pradesh        6958.0     6553
# ...           ...                          ...           ...      ...
# 15482  2020-08-15                  Uttarakhand      256008.0   225614
# 15483  2020-08-16                  Uttarakhand      260790.0   229387
# 15488  2020-08-21                  Uttarakhand      294279.0   258971
# 15528  2020-09-30                  Uttarakhand      712124.0   637547
# 15843  2020-04-01                  West Bengal         659.0      568
#
#        Positive  Total
# 0          12.0      0
# 453       132.0      0
# 454       365.0      0
# 455       381.0      0
# ...

# %%
df.loc[df['State'].str.startswith('H')]
# Out:
#             Date             State  TotalSamples Negative  Positive  Total
# 4966  2020-04-03           Haryana        1325.0      938      44.0      0
# 4967  2020-04-07           Haryana        2520.0     1821     141.0      0
# 4968  2020-04-08           Haryana        2650.0     1885     153.0      0
# 4969  2020-04-09           Haryana        2964.0     2017     156.0      0
# 4970  2020-04-10           Haryana        3527.0     2447     162.0      0
# ...          ...               ...           ...      ...       ...    ...
# 5581  2020-08-11  Himachal Pradesh      168843.0   164436    3497.0      0
# 5582  2020-08-12  Himachal Pradesh      171538.0   166391    3636.0      0
# 5583  2020-08-13  Himachal Pradesh      172985.0   168454    3816.0      0
# 5584  2020-08-14  Himachal Pradesh      175666.0   170882    3874.0      0
# 5585  2020-08-15  Himachal Pradesh      178075.0   173077    3993.0      0
#
# [275 rows x 6 columns]

# %%
df.loc[df['State'].str.endswith('d')]
# Out:
#              Date        State  TotalSamples Negative  Positive  Total
# 6435   2020-04-10    Jharkhand        1340.0     1326      14.0      0
# 6436   2020-04-11    Jharkhand        1546.0     1529      17.0      0
# 6437   2020-04-12    Jharkhand        1683.0     1666      17.0      0
# 6438   2020-04-13    Jharkhand        1982.0     1963      19.0      0
# 6439   2020-04-14    Jharkhand        2334.0     2307      27.0      0
# ...           ...          ...           ...      ...       ...    ...
# 15481  2020-08-14  Uttarakhand      251236.0   221085   11615.0      0
# 15482  2020-08-15  Uttarakhand      256008.0   225614   11940.0      0
# 15483  2020-08-16  Uttarakhand      260790.0   229387   12175.0      0
# 15488  2020-08-21  Uttarakhand      294279.0   258971   14083.0      0
# 15528  2020-09-30  Uttarakhand      712124.0   637547      65.0      0
#
# [617 rows x 6 columns]

# %%
df.to_csv("C://Users//Harish//Downloads//updatedStatewiseTestingDetails.csv")
